# %% [markdown]
# # Salary Prediction

# %%
# Import Statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#dataset import
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-55155d89-2bb3-4e3d-9b61-aba50c1b154f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55155d89-2bb3-4e3d-9b61-aba50c1b154f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving salary_dataset.csv to salary_dataset (1).csv
# {'salary_dataset.csv': b'YearsExperience,Salary\r\n1.1,39343.00\r\n1.3,46205.00\r\n1.5,37731.00\r\n2.0,43525.00\r\n2.2,39891.00\r\n2.9,56642.00\r\n3.0,60150.00\r\n3.2,54445.00\r\n3.2,64445.00\r\n3.7,57189.00\r\n3.9,63218.00\r\n4.0,55794.00\r\n4.0,56957.00\r\n4.1,57081.00\r\n4.5,61111.00\r\n4.9,67938.00\r\n5.1,66029.00\r\n5.3,83088.00\r\n5.9,81363.00\r\n6.0,93940.00\r\n6.8,91738.00\r\n7.1,98273.00\r\n7.9,101302.00\r\n8.2,113812.00\r\n8.7,109431.00\r\n9.0,105582.00\r\n9.5,116969.00\r\n9.6,112635.00\r\n10.3,122391.00\r\n10.5,121872.00\r\n'}

# %%
#importing dataset
data_set = pd.read_csv('salary_dataset.csv')

# %%
data_set
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data_set.isnull().any()
# Out:
# YearsExperience    False
# Salary             False
# dtype: bool

# %%
x = data_set.iloc[:,:1].values
y = data_set.iloc[:,1:].values

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(x,y,color='r')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg.predict(x_test)

# %%
y_pred
# Out:
# array([[ 40748.96184072],
#        [122699.62295594],
#        [ 64961.65717022],
#        [ 63099.14214487],
#        [115249.56285456],
#        [107799.50275317]])

# %%
y_test
# Out:
# array([[ 37731.],
#        [122391.],
#        [ 57081.],
#        [ 63218.],
#        [116969.],
#        [109431.]])

# %%
plt.scatter(x, y, color='r')
plt.plot(x, reg.predict(x), color = 'blue')

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

# %%
reg.fit(x_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(x, y, color='r')
plt.plot(x, reg.predict(poly.fit_transform(x)), color = 'blue')

# %%
y_pred = reg.predict(poly.fit_transform(x))

# %%
y_pred
# Out:
# array([[ 36419.97995933],
#        [ 38279.7051688 ],
#        [ 40140.74178358],
#        [ 44799.07071874],
#        [ 46664.69725209],
#        [ 53204.7174356 ],
#        [ 54140.31743855],
#        [ 56012.50099842],
#        [ 56012.50099842],
#        [ 60698.69729633],
#        [ 62575.47077478],
#        [ 63514.34929099],
#        [ 63514.34929099],
#        [ 64453.55565853],
#        [ 68213.65964195],
#        [ 71979.00924659],
#        [ 73863.65115687],
#        [ 75749.60447246],
#        [ 81415.33285105],
#        [ 82360.76839379],
#        [ 89936.05538347],
#        [ 92782.19755149],
#        [100386.33545789],
#        [103243.29671968],
#        [108011.45584918],
#        [110876.2855428 ],
#        [115657.55872536],
#        [116614.79691585],
#        [123324.64408643],
#        [125244.69393997]])

# %%
y
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])
